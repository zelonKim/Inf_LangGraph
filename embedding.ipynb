# %%
from dotenv import load_dotenv
load_dotenv() # .env 파일에서 환경변수를 로드함.
# Out:
# True

# %%
import os
from openai import OpenAI

client = OpenAI(
    api_key=os.getenv("UPSTAGE_API_KEY"), # .env 파일에 저장된 해당 키값을 가져옴.
    base_url="https://api.upstage.ai/v1/solar"
)

# %%
import numpy as np

def cosine_similarity(vec1, vec2): # 벡터간의 유사도를 계산하는 함수
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    
    if norm_vec1 == 0 or norm_vec2 == 0:
        return 0.0
    
    return dot_product / (norm_vec1 * norm_vec2)

# %%
king_embedding_response = client.embeddings.create(
    input="king",
    model="solar-embedding-1-large-query"
)

king_vector = np.array(king_embedding_response.data[0].embedding)
king_vector
# Out:
# array([-0.01187134, -0.02058411, -0.00674438, ..., -0.01082611,
#         0.00244713,  0.01517487], shape=(4096,))

# %%
queen_embedding_response = client.embeddings.create(
    input="queen",
    model="solar-embedding-1-large-query"
)

queen_vector = np.array(queen_embedding_response.data[0].embedding)
queen_vector
# Out:
# array([-0.00167722, -0.00950022, -0.0047052 , ...,  0.00988714,
#        -0.00728926,  0.02597879], shape=(4096,))

# %%
king_queen_similarity = cosine_similarity(king_vector, queen_vector)
print(king_queen_similarity)
# Out:
# 0.6277730015195628
