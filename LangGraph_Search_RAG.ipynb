# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model='text-embedding-3-large')

vector_store = Chroma(
    embedding_function = embeddings,
    collection_name = 'income_tax_collection2',
    persist_directory = './income_tax_collection2'
)

retriever = vector_store.as_retriever(search_kwargs={'k':3})

# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph
    
class AgentState(TypedDict):
    query: str
    context: list
    answer: str

# %%
def retrieve(state: AgentState):
    query = state['query']
    docs = retriever.invoke(query)
    
    return {'context': docs}

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model='gpt-4o')

# %%
from langchain import hub
from langchain_core.output_parsers import StrOutputParser

generate_prompt = hub.pull("rlm/rag-prompt")

def generate(state: AgentState):
    query = state['query']
    context = state['context']
    rag_chain = generate_prompt | llm | StrOutputParser()
    
    response = rag_chain.invoke({'question':query, 'context':context})
    
    return {'answer': response}

# %%
from typing import Literal

doc_relevance_prompt = hub.pull("langchain-ai/rag-document-relevance")

def check_doc_relevance(state: AgentState) -> Literal['relevant', 'irrelevant']:
    query = state['query']
    context = state['context']
    print(f'query: {query}')
    
    doc_relevance_chain = doc_relevance_prompt | llm
    response = doc_relevance_chain.invoke({'question':query, 'documents':context})
    print(f'response doc relevance: {response}')
    
    if response['Score'] == 1:
        return 'relevant'
    return 'irrelevant'

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate


rewrite_prompt = PromptTemplate.from_template("""
        사용자의 질문을 보고, 웹 검색에 용이하도록 사용자의 질문을 수정해주세요.
        질문: {question}    
""")


def rewrite(state: AgentState):
    query = state['query']
    rewrite_chain = rewrite_prompt | llm | StrOutputParser()

    response = rewrite_chain.invoke({'question': query})
    print(f'rewrite question: {response}')
    return {'query': response}

# %%
from langchain_community.tools import TavilySearchResults

search_tool = TavilySearchResults( # LLM이 직접 웹을 검색하기 위한 도구
    max_results = 3, # 검색 결과를 최대 3개 문서만 가져오도록 함.
    search_depth = "advanced", # 정확도가 향상된 검색을 수행함. / "basic": 빠르고 간단한 검색을 수행함.
    include_answer = True, # 검색 결과에 대한 Tavily의 답변을 포함시킴.
    include_raw_content = True, # 검색 결과에 웹 페이지의 원문 텍스트를 포함시킴.
    include_images = True # 검색 결과에 이미지 URL도 포함시킴.
)

def web_search(state: AgentState):
    query = state['query']
    results = search_tool.invoke(query) # 주어진 질문에 대해 웹 검색을 실행함. (list 타입의 값을 반환함.)
    print(f'web search results: {results}')
    return {'context': results}

# %%
graph_builder = StateGraph(AgentState)

# %%
graph_builder.add_node('retrieve', retrieve)
graph_builder.add_node('generate', generate)
graph_builder.add_node('rewrite', rewrite)
graph_builder.add_node('web_search', web_search)

# %%
from langgraph.graph import START, END

graph_builder.add_edge(START, 'retrieve')

graph_builder.add_conditional_edges(
    'retrieve',
    check_doc_relevance,
    {
        'relevant': 'generate',
        'irrelevant': 'rewrite',
    }
)

graph_builder.add_edge('rewrite', 'web_search')
graph_builder.add_edge('web_search', 'generate')
graph_builder.add_edge('generate', END)

# %%
graph = graph_builder.compile()

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
initial_state = { 'query': '강남역 근처 맛집을 추천해주세요.'}

graph.invoke(initial_state)
# Out:
# query: 강남역 근처 맛집을 추천해주세요.
# response doc relevance: {'Score': 0, 'Explanation': 'The facts provided are focused on tax laws and regulations, such as income tax, business reporting, and financial investment taxation. These topics are completely unrelated to the question about recommending a restaurant near Gangnam Station. There are no keywords or semantic meanings in the facts that relate to food, restaurants, or the Gangnam area, which are necessary to address the question. Therefore, the score is 0, indicating that the facts are completely unrelated to the question.'}
# rewrite question:
# 강남역 근처 인기 맛집 추천 리스트 부탁드립니다.
# web search results: [{'url': 'https://www.youtube.com/watch?v=WVssZrCxG4A', 'content': "# 강남에서만 '16,790끼' 먹은 의사의 Best 5 맛집 소개🍽️\n## 솔직한 의사 생활\n3600 subscribers\n15 likes\n\n### Description\n1414 views\nPosted: 20 Feb 2025\n안녕하세요☺️\n오늘은 36년간 강남에 계셨던 원장님께서\n'강남역 찐맛집'을 추천해 주시는 영상을 준비해 봤는데요 ㅎㅎ\n수많은 음식점이 즐비하는 강남에서 뭘 먹어야 할지 고민이신 분들은 이 영상을 끝까지 시청해 주세요! \n-\nMade with Vrew\n––––––––––––––––––––––––––––––––––––––––––––––––––\n#주름 #흉터 #시술 #쥬브젠 #자가진피재생술 #쥬브젠자가진피재생술 #강남 #맛집 #강남맛집 #추천 #맛집추천 #의사 [...] 우리 어릴 때 먹던 짜장면 집이죠 근데 몇 년 전에 그것도 없어졌어요 그래서 참 섭섭하게 생각합니다 그러면 마지막 한길에 강남역 주변에서 드실 수 있다고 하면 가고 싶은 곳이 있으신가 손님을 배려하거나 그런게 아니고 내가 진짜 입맛 에 맞아서 가고 싶다 마지막 한끼를 강남역에서 먹는다면 나는 번 6번 출고 뒷골목에 가서 안동국시를 먹겠습니다 경상도 말로는 이제 정부지 김치라고 하는 건데 그다음에 이제 깻잎은 간장에 절인 거죠 그게 참 맛있습니다 결국은 뭔가 하면 사람은 누구나 그런가 봐요 아무리 맛있고 비싸고 호화로운 식사보다 어릴 때 먹었던 그런 음식이 제일 인상적인 거 같습니다 그런 것들이 정서적으로 끌리는 거 같아요 저번에 갔던데 그렇지 그죠 그러면 처음 병원을 개업하 때 딱 강남에 오셔서 드셨던 음식이 있으세요 지금도 있습니다 모퉁이 라면 집이라고요 바로 뒤에 있습니다 그분이 저보다 오래 되셨습니다 저는 90년도 초에 개업을 했는데 그분은 88년도 말에 개업하다 듣고 [...] 뭐 기준이 있으신가요 옛날에는 정말 맛있는 거 찾고 많이 주는 거 찾아서 많이 옮겨 다녔죠 그런데 이제 음식을 먹고 부담스럽지 않았으면 좋겠다 고화가 되고 활동하는데 부담이 안 됐으면 좋겠다고 해서 조금 양 적고 그런 음식점을 찾게 됩니다 최근에는 그러면 저희가 병원에 좀 먼 지방이나 해외 환자분들이 많이 찾아와 주시잖아요 병원 근처에 좀 추천드릴 수 있는 맛집은 어디가 있을까요 어 제가는 범위내에서 설명을 드리면 강남역에서 저기 번 출구나 가면 을밀대 하는 우리나라에 유명한 냉면집 있어요 그다음에 이제 거기서 번 출구 사이에 조금 오면 일식 우동집이 있습니다 기리 아마라 하는 우동집이 있고 그다음에 이제 6번 출구 저작에 가면 거기 안동국시 집도 있고 9번 출구 쪽으로 나가서 교대역 쪽으로 조금 가다가 첫째 골목에서 우회전을 해서 가면 딘다이펑이라고 하는 만두집 있습니다 그 집도 상당히 유명하기도 하고 별로 실망하지 않습니다 그러고 이제 10번 출구에서 쭉 한참 올라가면 그"}, {'url': 'https://www.leebommat.com/restaurant/content/57', 'content': "서울 강남은 다양한 맛집들이 즐비해 있어, 미식가들에게는 천국과도 같은 곳입니다. 최근 성시경이 그의 유튜브 프로그램에서 소개한 맛집들 중에는 전통적인 한식에서부터 현대적인 중식, 그리고 독특한 분위기의 이색 주점까지 다양하게 자리 잡고 있습니다. 이곳들은 일반적인 맛집과는 다른 특별한 매력으로 많은 사랑을 받고 있으며, 각 음식점마다 색다른 경험을 제공합니다. 강남에서 맛있는 음식을 즐기고 싶다면 무조건 체크해야 할 리스트에 올려야 할 곳들이 가득합니다. 신선한 재료와 정성으로 만든 요리들은 식사 한 끼를 단순한 끼니가 아닌, 특별한 경험으로 변화시켜 줄 것입니다. 압구정의 숨겨진 보석 같은 맛집에서부터 강남 한복판의 전통 맛집까지, 성시경이 추천하는 음식들을 통해 강남의 미각을 탐험해 보세요. 이곳들은 맛뿐만 아니라 분위기와 서비스까지, 방문하는 모든 이들에게 만족을 선사할 것입니다.\n\n키워드 [...] “강남역의 밤을 밝히는 해장국 명소, 강남진해장” 서울 강남구에 위치한 '강남진해장'은 언제든지 뜨끈한 해장국과 곱창전골을 즐길 수 있는 24시간 운영되는 맛집입니다. 강남역 12번 출구에서 도보로 1분 거리에 위치해 있어, 늦은 시간에도 편리하게 방문할 수 있는 매력이 있습니다. 이곳의 대표 메뉴인 양선지해장국은 신선한 선지와 아삭한 콩나물이 푸짐하게 들어가 있으며, 깊고 시원한 국물 맛이 일품입니다. 특히, 주문과 동시에 제공되는 다양한 김치와 반찬들은 해장국의 감칠맛을 더욱 살려줍니다. 또한, 곱창전골은 신선한 재료들과 매콤한 양념이 어우러져, 얼큰한 국물과 함께 깊은 풍미를 자랑합니다. '강남진해장'은 성시경의 유튜브 프로그램에 소개되어 유명세를 더했으며, 맛과 품질 모두를 갖춘 곳으로, 해장뿐만 아니라 친구들과의 술자리에도 안성맞춤입니다. 푸짐한 양과 합리적인 가격으로 많은 이들의 사랑을 받고 있는 이곳에서 소중한 한 끼를 즐겨보세요.\n\n위치 안내\n\n최신 맛집 소식 [...] 함께하는 특별한 시간을 제공하는 곳으로, 강남의 맛집 중 하나로 기억될 것입니다. 전통의 맛을 계승하며, 오랜 단골 손님들의 사랑을 받고 있는 이곳에서 진정한 족발의 매력을 느껴보세요."}, {'url': 'https://m.blog.naver.com/twin_couple/222831691893', 'content': '추천메뉴 : 제육+계란말이\n\n가격대 : 만원초반대\n\n맛나직화구이\n\n서울특별시 서초구 서초대로74길 23\n\n\u200b\n\n여기까지 최근에 제가 다녀온 강남역 맛집 모음 14군데 포스팅이었구요. 혹시 강남역 근처 오신다면, #강남역직장인 이면서 10년째 #맞벌이육아 하며 #워킹맘으로 살고있는 저를 찾아주세요ㅋ 같이 육아나 커리어에 대한 고민을 나눠봐요~~^^ #서비스기획, #UX디자인 도 15년차라 직무나 #커리어 관련해서도 #커피챗 환영합니다 :)\n\n\u200b\n\n\u200b\u200b\n\n\u200b\n\n\u200b\n\n\u200b\n\n\u200b\n\n\u200b\n\n▼ 강남역 내돈내산 직장인 점심 맛집 모음 1탄\n\n강남역 맛집 내돈내산 11군데 모음\n\n강남역 맛집은 내 의지로 간다기보단, 회사사람들과의 점심약속은 다들 외식을 선호하다보니까 그렇게 많이...\n\nblog.naver.com\n\n\u200b\n\n\u200b\n\n\u200b\n\n▼ 강남역 내돈내산 직장인 점심 맛집 모음 2탄\n\n강남역 맛집 내돈내산 12군데 모음 [...] 아 내가 타코를 좋아해서, 가격대가 있음에도 불구하고 자주 가는 곳인데........ 전에도 후기 남긴 적 있고. 이 날 이후로 안 가고 있다ㅋㅋㅋㅋㅋ 그 날 점원이 분명 주문 받았는데 누락됐다고 해서...........;;; 진짜 오래 기다렸다 늦게 먹었음ㅠㅜㅠ 죄송하다는 의미로 에이드를 주셔서...... 아무 말 못하고 먹고왔지만 1시를 넘겨 부서장님의 눈총을 받았다고 한다..........ㅋ (당연히 넘긴 시간은 비업무로 차감함) 하지만 새우 고기 듬뿍에 화이타도 리필되고, 맛도 맛있고 인스타 감성 맛집으로도 괜춘. 가격대는 좀 있음;;ㅎ\n\n강남역 맛집 내돈내산 11군데 모음\n\n강남역 맛집은 내 의지로 간다기보단, 회사사람들과의 점심약속은 다들 외식을 선호하다보니까 그렇게 많이...\n\nblog.naver.com\n\n\u200b\n\n\u200b\n\n강남역 맛집 낙원타코\n\n#추천메뉴 : 낙원화이타\n\n#가격대 : 2만원\n\n낙원타코 강남역점\n\n서울특별시 서초구 서초대로73길 9 타임빌딩 2층\n\n\u200b\n\n\u200b [...] 와 선지 좋아하는 사람은 여기 미칠 거 같다........ 제주도에서도 못 가보던 은희네 해장국을 강남에서 먹을 수 있네?ㅋㅋㅋㅋㅋㅋㅋㅋ 선지 내장 당면 우거지 국물 다 너무 맛있음!! 만족감 200%.............. 선지 좋아하는 사람 찾기가 힘들어 그렇지 1번 가봤지만 내 최애 맛집으로 등극!!\n\n\u2 ...
# {'query': '\n강남역 근처 인기 맛집 추천 리스트 부탁드립니다.',
#  'context': [{'url': 'https://www.youtube.com/watch?v=WVssZrCxG4A',
#    'content': "# 강남에서만 '16,790끼' 먹은 의사의 Best 5 맛집 소개🍽️\n## 솔직한 의사 생활\n3600 subscribers\n15 likes\n\n### Description\n1414 views\nPosted: 20 Feb 2025\n안녕하세요☺️\n오늘은 36년간 강남에 계셨던 원장님께서\n'강남역 찐맛집'을 추천해 주시는 영상을 준비해 봤는데요 ㅎㅎ\n수많은 음식점이 즐비하는 강남에서 뭘 먹어야 할지 고민이신 분들은 이 영상을 끝까지 시청해 주세요! \n-\nMade with Vrew\n––––––––––––––––––––––––––––––––––––––––––––––––––\n#주름 #흉터 #시술 #쥬브젠 #자가진피재생술 #쥬브젠자가진피재생술 #강남 #맛집 #강남맛집 #추천 #맛집추천 #의사 [...] 우리 어릴 때 먹던 짜장면 집이죠 근데 몇 년 전에 그것도 없어졌어요 그래서 참 섭섭하게 생각합니다 그러면 마지막 한길에 강남역 주변에서 드실 수 있다고 하면 가고 싶은 곳이 있으신가 손님을 배려하거나 그런게 아니고 내가 진짜 입맛 에 맞아서 가고 싶다 마지막 한끼를 강남역에서 먹는다면 나는 번 6번 출고 뒷골목에 가서 안동국시를 먹겠습니다 경상도 말로는 이제 정부지 김치라고 하는 건데 그다음에 이제 깻잎은 간장에 절인 거죠 그게 참 맛있습니다 결국은 뭔가 하면 사람은 누구나 그런가 봐요 아무리 맛있고 비싸고 호화로운 식사보다 어릴 때 먹었던 그런 음식이 제일 인상적인 거 같습니다 그런 것들이 정서적으로 끌리는 거 같아요 저번에 갔던데 그렇지 그죠 그러면 처음 병원을 개업하 때 딱 강남에 오셔서 드셨던 음식이 있으세요 지금도 있습니다 모퉁이 라면 집이라고요 바로 뒤에 있습니다 그분이 저보다 오래 되셨습니다 저는 90년도 초에 개업을 했는데 그분은 88년도 말에 개업하다 듣고 [...] 뭐 기준이 있으신가요 옛날에는 정말 맛있는 거 찾고 많이 주는 거 찾아서 많이 옮겨 다녔죠 그런데 이제 음식을 먹고 부담스럽지 않았으면 좋겠다 고화가 되고 활동하는데 부담이 안 됐으면 좋겠다고 해서 조금 양 적고 그런 음식점을 찾게 됩니다 최근에는 그러면 저희가 병원에 좀 먼 지방이나 해외 환자분들이 많이 찾아와 주시잖아요 병원 근처에 좀 추천드릴 수 있는 맛집은 어디가 있을까요 어 제가는 범위내에서 설명을 드리면 강남역에서 저기 번 출구나 가면 을밀대 하는 우리나라에 유명한 냉면집 있어요 그다음에 이제 거기서 번 출구 사이에 조금 오면 일식 우동집이 있습니다 기리 아마라 하는 우동집이 있고 그다음에 이제 6번 출구 저작에 가면 거기 안동국시 집도 있고 9번 출구 쪽으로 나가서 교대역 쪽으로 조금 가다가 첫째 골목에서 우회전을 해서 가면 딘다이펑이라고 하는 만두집 있습니다 그 집도 상당히 유명하기도 하고 별로 실망하지 않습니다 그러고 이제 10번 출구에서 쭉 한참 올라가면 그"},
#   {'url': 'https://www.leebommat.com/restaurant/content/57',
#    'content': "서울 강남은 다양한 맛집들이 즐비해 있어, 미식가들에게는 천국과도 같은 곳입니다. 최근 성시경이 그의 유튜브 프로그램에서 소개한 맛집들 중에는 전통적인 한식에서부터 현대적인 중식, 그리고 독특한 분위기의 이색 주점까지 다양하게 자리 잡고 있습니다. 이곳들은 일반적인 맛집과는 다른 특별한 매력으로 많은 사랑을 받고 있으며, 각 음식점마다 색다른 경험을 제공합니다. 강남에서 맛있는 음식을 즐기고 싶다면 무조건 체크해야 할 리스트에 올려야 할 곳들이 가득합니다. 신선한 재료와 정성으로 만든 요리들은 식사 한 끼를 단순한 끼니가 아닌, 특별한 경험으로 변화시켜 줄 것입니다. 압구정의 숨겨진 보석 같은 맛집에서부터 강남 한복판의 전통 맛집까지, 성시경이 추천하는 음식들을 통해 강남의 미각을 탐험해 보세요. 이곳들은 맛뿐만 아니라 분위기와 서비스까지, 방문하는 모든 이들에게 만족을 선사할 것입니다.\n\n키워드 [...] “강남역의 밤을 밝히는 해장국 명소, 강남진해장” 서울 강남구에 위치한 '강남진해장'은 언제든지 뜨끈한 해장국과 곱창전골을 즐길 수 있는 24시간 운영되는 맛집입니다. 강남역 12번 출구에서 도보로 1분 거리에 위치해 있어, 늦은 시간에도 편리하게 방문할 수 있는 매력이 있습니다. 이곳의 대표 메뉴인 양선지해장국은 신선한 선지와 아삭한 콩나물이 푸짐하게 들어가 있으며, 깊고 시원한 국물 맛이 일품입니다. 특히, 주문과 동시에 제공되는 다양한 김치와 반찬들은 해장국의 감칠맛을 더욱 살려줍니다. 또한, 곱창전골은 신선한 재료들과 매콤한 양념이 어우러져, 얼큰한 국물과 함께 깊은 풍미를 자랑합니다. '강남진해장'은 성시경의 유튜브 프로그램에 소개되어 유명세를 더했으며, 맛과 품질 모두를 갖춘 곳으로, 해장뿐만 아니라 친구들과의 술자리에도 안성맞춤입니다. 푸짐한 양과 합리적인 가격으로 많은 이들의 사랑을 받고 있는 이곳에서 소중한 한 끼를 즐겨보세요.\n\n위치 안내\n\n최신 맛집 소식 [...] 함께하는 특별한 시간을 제공하는 곳으로, 강남의 맛집 중 하나로 기억될 것입니다. 전통의 맛을 계승하며, 오랜 단골 손님들의 사랑을 받고 있는 이곳에서 진정한 족발의 매력을 느껴보세요."},
#   {'url': 'https://m.blog.naver.com/twin_couple/222831691893',
#    'content': '추천메뉴 : 제육+계란말이\n\n가격대 : 만원초반대\n\n맛나직화구이\n\n서울특별시 서초구 서초대로74길 23\n\n\u200b\n\n여기까지 최근에 제가 다녀온 강남역 맛집 모음 14군데 포스팅이었구요. 혹시 강남역 근처 오신다면, #강남역직장인 이면서 10년째 #맞벌이육아 하며 #워킹맘으로 살고있는 저를 찾아주세요ㅋ 같이 육아나 커리어에 대한 고민을 나눠봐요~~^^ #서비스기획, #UX디자인 도 15년차라 직무나 #커리어 관련해서도 #커피챗 환영합니다 :)\n\n\u200b\n\n\u200b\u200b\n\n\u200b\n\n\u200b\n\n\u200b\n\n\u200b\n\n\u200b\n\n▼ 강남역 내돈내산 직장인 점심 맛집 모음 1탄\n\n강남역 맛집 내돈내산 11군데 모음\n\n강남역 맛집은 내 의지로 간다기보단, 회사사람들과의 점심약속은 다들 외식을 선호하다보니까 그렇게 많이...\n\nblog.naver.com\n\n\u200b\n\n\u200b\n\n\u200b\n\n▼ 강남역 내돈내산 직장인 점심 맛집 모음 2탄\n\n강남역 맛집 내돈내산 12군데 모음 [...] 아 내가 타코를 좋아해서, 가격대가 있음에도 불구하고 자주 가는 곳인데........ 전에도 후기 남긴 적 있고. 이 날 이후로 안 가고 있다ㅋㅋㅋㅋㅋ 그 날 점원이 분명 주문 받았는데 누락됐다고 해서...........;;; 진짜 오래 기다렸다 늦게 먹었음ㅠㅜㅠ 죄송하다는 의미로 에이드를 주셔서...... 아무 말 못하고 먹고왔지만 1시를 넘겨 부서장님의 눈총을 받았다고 한다..........ㅋ (당연히 넘긴 시간은 비업무로 차감함) 하지만 새우 고기 듬뿍에 화이타도 리필되고, 맛도 맛있고 인스타 감성 맛집으로도 괜춘. 가격대는 좀 있음;;ㅎ\n\n강남역 맛집 내돈내산 11군데 모음\n\n강남역 맛집은 내 의지로 간다기보단, 회사사람들과의 점심약속은 다들 외식을 선호하다보니까 그렇게 많이...\n\nblog.naver.com\n\n\u200b\n\n\u200b\n\n강남역 맛집 낙원타코\n\n#추천메뉴 : 낙원화이타\n\n#가격대 : 2만원\n\n낙원타코 강남역점\n\n서울특별시 서초구 서초대로73길 9 타임빌딩 2층\n\n\u200b\n\n\u200b [...] 와 선지 좋아하는 사람은 여기 미칠 거 같다........ 제주도에서도 못 가보던 은희네 해장국을 강남에서 먹을 수 있네?ㅋㅋㅋㅋㅋㅋㅋㅋ 선지 내장 당면 우거지 국물 다 너무 맛있음!! 만족감 200%.............. 선지 좋아하는 사람 찾기가 힘들어 그렇지 1번 가봤지만 내 최애 맛집으로 등극!!\n\n\u200b\n\n\u200b\n\n강남역 맛집 제주은희네해장국 강남역점\n\n추천메뉴 : 해장국\n\n가격대 : 만원\n\n제주은희네해장국 강남역점\n\n서울특별시 강남구 테헤란로8길 11\n\n\u200b\n\n\u200b\n\n\u200b\n\n\u200b\n\n\u200b\n\n9. 강남역 맛집 : 해우담\n\n해우담 좋아해서 진짜 자주가는데 룸이 있기도 하고, 가격도 착하고, 음식도 정갈 건강하고.. 이 날 고등어 구이가 좀... 너무 바싹 익혀나와서 좀 마른 느낌이었음;;; 쩝.......... 오랜만에 멀리서 온 친구 사주는 건데 미안했음ㅠㅜㅠㅠㅜ 하지만 늘 좋아하는 내 해우담ㅋ\n\n강남역 맛집 내돈내산 12군데 모음'}],
#  'answer': "강남역 근처의 인기 맛집으로는 '강남진해장', '낙원타코 강남역점', 그리고 '제주은희네해장국 강남역점'이 추천됩니다. '강남진해장'은 24시간 운영하며 해장국과 곱창전골이 유명하고, '낙원타코'는 인스타 감성의 멕시칸 음식점으로 화이타가 추천 메뉴입니다. '제주은희네해장국'은 해장국이 인기 있으며, 신선한 선지와 다양한 재료로 깊은 맛을 제공합니다."}
